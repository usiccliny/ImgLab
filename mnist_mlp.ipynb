# %%
from __future__ import print_function
import keras
from keras.optimizers import RMSprop
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
image_size = (28, 28)
num_classes = 10
num_images_per_class = 1000

x_data = []
y_data = []

output_folder = 'digit_images'

for digit in range(num_classes):
    digit_folder = os.path.join(output_folder, str(digit))
    for i in range(num_images_per_class):
        image_path = os.path.join(digit_folder, f'{digit}_{i}.png')
        if os.path.exists(image_path):
            img = Image.open(image_path).convert('L')
            img = img.resize(image_size)
            img_array = np.array(img)

            img_array = img_array.astype('float32') / 255.0
            
            x_data.append(img_array.flatten())
            y_data.append(digit)

x_data = np.array(x_data)
y_data = np.array(y_data)

y_data = to_categorical(y_data, num_classes)

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=20,
                    validation_data=(x_test, y_test),
                    verbose=1)

score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/20
# c:\Users\usicc\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0951 - loss: 2.5644 - val_accuracy: 0.0930 - val_loss: 2.3037
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1000 - loss: 2.3050 - val_accuracy: 0.0960 - val_loss: 2.3029
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0971 - loss: 2.3027 - val_accuracy: 0.0875 - val_loss: 2.3031
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1068 - loss: 2.3025 - val_accuracy: 0.0875 - val_loss: 2.3033
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1082 - loss: 2.3023 - val_accuracy: 0.0875 - val_loss: 2.3034
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1053 - loss: 2.3024 - val_accuracy: 0.0875 - val_loss: 2.3034
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1042 - loss: 2.3024 - val_accuracy: 0.0875 - val_loss: 2.3033
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1054 - loss: 2.3026 - val_accuracy: 0.0875 - val_loss: 2.3033
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1018 - loss: 2.3025 - val_accuracy: 0.0875 - val_loss: 2.3036
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1062 - loss: 2.3024 - val_accuracy: 0.0875 - val_loss: 2.3035
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1008 - loss: 2.3027 - val_accuracy: 0.0875 - val_loss: 2.3035
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1007 - loss: 2.3027 - val_accuracy: 0.0875 - val_loss: 2.3035
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1062 - loss: 2.3025 - val_accuracy: 0.0875 - val_loss: 2.3034
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1009 - loss: 2.3027 - val_accuracy: 0.0875 - val_loss: 2.3036
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1044 - loss: 2.3026 - val_accuracy: 0.0875 - val_loss: 2.3035
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1064 - loss: 2.3025 - val_accuracy: 0.0875 - val_loss: 2.3035
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1096 - loss: 2.3022 - val_accuracy: 0.0875 - val_loss: 2.3035
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1066 - loss: 2.3026 - val_accuracy: 0.0875 - val_loss: 2.3035
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1049 - loss: 2.3024 - val_accuracy: 0.0875 - val_loss: 2.3035
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1062 - loss: 2.3025 - val_accuracy: 0.0875 - val_loss: 2.3034
# Test loss: 2.303408145904541
# Test accuracy: 0.08749999850988388

# %%
image_size = (28, 28)
num_classes = 10 
num_images_per_class = 1000

x_data = []
y_data = []

output_folder = 'digit_images'

for digit in range(num_classes):
    digit_folder = os.path.join(output_folder, str(digit))
    for i in range(num_images_per_class):
        image_path = os.path.join(digit_folder, f'{digit}_{i}.png')
        if os.path.exists(image_path):
            img = Image.open(image_path).convert('L')
            img = img.resize(image_size)
            img_array = np.array(img)

            img_array = img_array.astype('float32') / 255.0
            
            x_data.append(img_array.flatten())
            y_data.append(digit)

x_data = np.array(x_data)
y_data = np.array(y_data)

y_data = to_categorical(y_data, num_classes)

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(784,)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=20,
                    validation_data=(x_test, y_test),
                    verbose=1)

score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()

plt.show()
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.1706 - loss: 2.8202 - val_accuracy: 0.1010 - val_loss: 13.3607
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3806 - loss: 1.7099 - val_accuracy: 0.1010 - val_loss: 42.7577
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5159 - loss: 1.3030 - val_accuracy: 0.1010 - val_loss: 100.2069
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6315 - loss: 0.9751 - val_accuracy: 0.1010 - val_loss: 163.1343
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7036 - loss: 0.7759 - val_accuracy: 0.1010 - val_loss: 213.4261
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7523 - loss: 0.6466 - val_accuracy: 0.1010 - val_loss: 253.7091
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7887 - loss: 0.5428 - val_accuracy: 0.1010 - val_loss: 247.4614
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8150 - loss: 0.4746 - val_accuracy: 0.1010 - val_loss: 246.3793
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8464 - loss: 0.3885 - val_accuracy: 0.1010 - val_loss: 205.3219
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8504 - loss: 0.3734 - val_accuracy: 0.1010 - val_loss: 201.7053
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8719 - loss: 0.3370 - val_accuracy: 0.1010 - val_loss: 178.0521
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8777 - loss: 0.3108 - val_accuracy: 0.1010 - val_loss: 165.0151
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8868 - loss: 0.2857 - val_accuracy: 0.1010 - val_loss: 147.7006
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8888 - loss: 0.2766 - val_accuracy: 0.1010 - val_loss: 140.0929
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9031 - loss: 0.2448 - val_accuracy: 0.1010 - val_loss: 126.2836
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8992 - loss: 0.2503 - val_accuracy: 0.1010 - val_loss: 131.2127
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8908 - loss: 0.2524 - val_accuracy: 0.1010 - val_loss: 109.5816
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9191 - loss: 0.2041 - val_accuracy: 0.1010 - val_loss: 104.6788
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9066 - loss: 0.2229 - val_accuracy: 0.1010 - val_loss: 97.7157
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9119 - loss: 0.2168 - val_accuracy: 0.1010 - val_loss: 83.2751
# Test loss: 83.27507781982422
# Test accuracy: 0.10100000351667404
